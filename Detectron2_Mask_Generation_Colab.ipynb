# %% [markdown]
# ## Step 1: Install Dependencies

# %%
# Install required packages
# !pip install pyyaml==5.1 -q
# !pip install torch torchvision -q
# !pip install tifffile opencv-python -q

# Clone and install Detectron2
# !git clone 'https://github.com/facebookresearch/detectron2' -q
# !cd detectron2 && pip install -e . -q

print("✅ Dependencies installed successfully")

# %% [markdown]
# ## Step 2: Import Libraries and Setup

# %%
import sys
sys.path.insert(0, '/content/detectron2')

import torch
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

import numpy as np
import os
import cv2
import tifffile
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog

print(f"✅ PyTorch: {torch.__version__}")
print(f"✅ CUDA available: {torch.cuda.is_available()}")
print(f"✅ Detectron2: {detectron2.__version__}")

# %% [markdown]
# ## Step 3: Mount Google Drive and Setup Paths
#
# This allows access to your image stacks and model weights on Google Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

print("✅ Google Drive mounted")

# %% [markdown]
# ## Step 4: Configure Model
#
# **USER INPUT REQUIRED:** Update these paths with your model location

# %%
# ============= USER CONFIGURATION =============

# Path to your trained model weights
MODEL_WEIGHTS_PATH = "/content/drive/MyDrive/path/to/your/model_final.pth"

# Number of classes in your model
NUM_CLASSES = 6

# Class names (must match training order)
CLASS_NAMES = ["mitochondria", "pseudopod", "unfused_MO", "MO", "sperm_cell", "nucleus"]

# Score threshold for predictions (higher = more confident, fewer detections)
SCORE_THRESHOLD = 0.05

# ============= END USER CONFIGURATION =============

# %% [markdown]
# ## Step 5: Initialize Predictor

# %%
# Load Detectron2 configuration
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

# Set model weights and number of classes
cfg.MODEL.WEIGHTS = MODEL_WEIGHTS_PATH
cfg.MODEL.ROI_HEADS.NUM_CLASSES = NUM_CLASSES
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = SCORE_THRESHOLD

# Initialize predictor
predictor = DefaultPredictor(cfg)

# Setup metadata for visualization
metadata = MetadataCatalog.get("coco_2014_val")
metadata.thing_classes = CLASS_NAMES

print(f"✅ Model loaded from: {MODEL_WEIGHTS_PATH}")
print(f"✅ Classes: {CLASS_NAMES}")

# %% [markdown]
# ## Step 6: Process Image Stack
#
# **USER INPUT REQUIRED:** Update input/output paths

# %%
# ============= USER INPUT =============

# Path to input TIFF stack (SEM images)
STACK_PATH = "/content/drive/MyDrive/path/to/your/image_stack.tif"

# Output directory (will be created if doesn't exist)
OUTPUT_DIR = "/content/drive/MyDrive/path/to/output/masks"

# ============= END USER INPUT =============

# %%
# Create output directories
os.makedirs(OUTPUT_DIR, exist_ok=True)
overall_folder = os.path.join(OUTPUT_DIR, "visualization_overlays")
os.makedirs(overall_folder, exist_ok=True)

# Create per-class folders
for class_name in CLASS_NAMES:
    class_folder = os.path.join(OUTPUT_DIR, class_name)
    os.makedirs(class_folder, exist_ok=True)

print(f"✅ Created output directories in: {OUTPUT_DIR}")

# Load image stack
image_stack = tifffile.imread(STACK_PATH)
num_slices = image_stack.shape[0]
print(f"✅ Loaded image stack with {num_slices} slices")

# %%
# Initialize storage for masks
combined_masks_dict = {class_name: [] for class_name in CLASS_NAMES}
overall_predictions = []

# Process each slice
for slice_idx in range(num_slices):
    # Extract slice and convert to 3-channel if needed
    slice_img = image_stack[slice_idx]
    if len(slice_img.shape) == 2:
        slice_img_color = cv2.cvtColor(slice_img, cv2.COLOR_GRAY2BGR)
    else:
        slice_img_color = slice_img

    # Run prediction
    outputs = predictor(slice_img_color)
    pred_classes = outputs["instances"].pred_classes.cpu().numpy()
    pred_masks = outputs["instances"].pred_masks.cpu().numpy()

    H, W = slice_img_color.shape[:2]

    # Create per-class binary masks
    for class_idx, class_name in enumerate(CLASS_NAMES):
        combined_mask = np.zeros((H, W), dtype=np.uint8)
        for i, pred_class in enumerate(pred_classes):
            if pred_class < len(CLASS_NAMES) and CLASS_NAMES[pred_class] == class_name:
                mask = (pred_masks[i].astype(np.uint8)) * 255
                combined_mask = cv2.bitwise_or(combined_mask, mask)
        combined_masks_dict[class_name].append(combined_mask)

    # Create visualization
    v = Visualizer(slice_img_color[:, :, ::-1], metadata=metadata)
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    overall_img = out.get_image()[:, :, ::-1]
    overall_predictions.append(overall_img)

    # Save visualization
    overall_output_path = os.path.join(overall_folder, f"slice_{slice_idx:04d}.png")
    cv2.imwrite(overall_output_path, overall_img)

    # Progress update
    if (slice_idx + 1) % 10 == 0 or slice_idx == 0:
        print(f"Processed slice {slice_idx + 1}/{num_slices}")

print(f"✅ Finished processing all {num_slices} slices")

# %% [markdown]
# ## Step 7: Save Binary Mask Stacks

# %%
# Save per-class mask stacks as TIFF
for class_name, mask_list in combined_masks_dict.items():
    if len(mask_list) == 0:
        print(f"⚠️  No masks for class '{class_name}'")
        continue

    # Convert to 3D array and save
    stack_array = np.array(mask_list)
    class_folder = os.path.join(OUTPUT_DIR, class_name)
    stack_filename = os.path.join(class_folder, f"{class_name}_stack.tif")
    tifffile.imwrite(stack_filename, stack_array)
    
    print(f"✅ Saved {class_name}: {len(mask_list)} slices → {stack_filename}")

print(f"\n✅ All masks saved to: {OUTPUT_DIR}")

# %% [markdown]
# ## Step 8: Download Results
#
# Files are ready to download from Google Drive. Check the output folder on your Drive.

# %%
print(f"""\n📁 OUTPUT STRUCTURE:
{OUTPUT_DIR}/
├── mitochondria/
│   └── mitochondria_stack.tif
├── nucleus/
│   └── nucleus_stack.tif
├── pseudopod/
│   └── pseudopod_stack.tif
├── MO/
│   └── MO_stack.tif
├── unfused_MO/
│   └── unfused_MO_stack.tif
├── sperm_cell/
│   └── sperm_cell_stack.tif
└── visualization_overlays/
    ├── slice_0000.png
    ├── slice_0001.png
    └── ...

✅ Ready to use with the Sperm Cell Analysis Pipeline!
""")
